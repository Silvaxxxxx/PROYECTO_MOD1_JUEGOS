# %%
import random
def jugar_piedra():
    jugador_nombre = input("Escribe tu nombre aquí").capitalize()
    print("Bienvenido al juego", jugador_nombre)

    jugador1 = input('Escoge tu elemento : Piedra, Papel o Tijera').capitalize()
    print("Has escogido:", jugador1) 

    elemento = ('Piedra', 'Papel', 'Tijera')
    jugador2 = random.choice(elemento)
    print("Elemento ordenador", jugador2)#chivato, te sale antes de que tu pongas nada


    vida = 3
    while vida != 6 and vida != 0:
        jugador2 = random.choice(elemento)
        print(jugador2)   # este print revisar con el equipo (este print va fuera)
        jugador1 = input('Escoge tu elemento : Piedra, Papel o Tijera').capitalize()
        print("Has escogido:", jugador1)
        if jugador1 == 'Piedra':
            if jugador2 == 'Tijera':
                vida += 1
                print('Has ganado un punto')
            elif  jugador2 == 'Papel':
                vida -= 1
                print('Has perdido la ronda')
            else:
                print('Has empatado')


        elif jugador1 == 'Papel':
            if jugador2 == 'Piedra':
                vida += 1
                print('Has ganado un punto')
            elif jugador2 == 'Tijera':
                vida -= 1
                print('Has perdido la ronda')
            else:
                print('Has empatado')
   
        elif jugador1 == 'Tijera':
            if jugador2 == 'Papel':
                vida += 1
                print('Has ganado un punto')
            elif jugador2 == 'Piedra':
                vida -= 1
                print('Has perdido la ronda')
            else:
                print('Has empatado')
        else:
            print("La palabra introducida no es válida")
        
    if vida == 6:
        print("Te has pasado el juego")
    elif vida == 0:
        print("Game over")

# %%
jugar_piedra()
# Out:
# Bienvenido al juego Bianca
# Has escogido: Piedra
# Elemento ordenador Piedra
# Tijera
# Has escogido: Tijera
# Has empatado
# Piedra
# Has escogido: Piedra
# Has empatado
# Papel
# Has escogido: Tijera
# Has ganado un punto
# Papel
# Has escogido: Tijera
# Has ganado un punto
# Tijera
# Has escogido: Tijera
# Has empatado
# Piedra
# Has escogido: Piedra
# Has empatado
# Piedra
# Has escogido: Papel
# Has ganado un punto
# Te has pasado el juego

# %%
#código roto 
import random
def jugar_piedra():
    jugador_nombre = input("Escribe tu nombre aquí").capitalize()
    print("Bienvenido al juego", jugador_nombre)
    elemento = ('Piedra', 'Papel', 'Tijera')
    
    #chivato, te sale antes de que tu pongas nada
    vida = 3
    while vida != 6 or vida != 0:
        jugador2 = random.choice(elemento)
        # este print revisar con el equipo (este print va fuera)
        jugador1 = input('Escoge tu elemento : Piedra, Papel o Tijera').capitalize()
        print("Has escogido:", jugador1)
        if jugador1 == 'Piedra':
            if jugador2 == 'Tijera':
                vida += 1
                print('Has ganado un punto')
            elif  jugador2 == 'Papel':
                vida -= 1
                print('Has perdido la ronda')
            else:
                print('Has empatado')


        elif jugador1 == 'Papel':
            if jugador2 == 'Piedra':
                vida += 1
                print('Has ganado un punto')
            elif jugador2 == 'Tijera':
                vida -= 1
                print('Has perdido la ronda')
            else:
                print('Has empatado')
   
        elif jugador1 == 'Tijera':
            if jugador2 == 'Papel':
                vida += 1
                print('Has ganado un punto')
            elif jugador2 == 'Piedra':
                vida -= 1
                print('Has perdido la ronda')
            else:
                print('Has empatado')
        else:
            print("La palabra introducida no es válida")
        
    if vida == 6:
        print("Te has pasado el juego")
    elif vida == 0:
        print("Game over")

# %%
jugar_piedra()
# Out:
# Bienvenido al juego
# Has escogido: Bianca
# La palabra introducida no es válida
# Has escogido: Piedra
# Has empatado
# Has escogido: Piedra
# Has empatado
# Has escogido: Piedra
# Has empatado
# Has escogido: Piedra
# Has empatado
# Has escogido: Tijera
# Has ganado un punto
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# Has escogido:
# La palabra introducida no es válida
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
