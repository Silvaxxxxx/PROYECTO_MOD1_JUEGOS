# %%
import random
jugador_nombre = input("Escribe tu nombre aquí").capitalize()
print("Bienvenido al juego", jugador_nombre)

jugador1 = input('Escoge tu elemento : Piedra, Papel o Tijera').capitalize()
print("Has escogido:", jugador1) # este no se necesita (?¿)

elemento = ('Piedra', 'Papel', 'Tijera')
jugador2 = random.choice(elemento)
print("Elemento ordenador", jugador2)


vida = 3
while vida != 6 and vida != 0:
    jugador2 = random.choice(elemento)
    print(jugador2)   # este print revisar con el equipo (este print va fuera)
    jugador1 = input('Escoge tu elemento : Piedra, Papel o Tijera').capitalize()
    print("Has escogido:", jugador1)
    if jugador1 == 'Piedra':
        if jugador2 == 'Tijera':
            vida += 1
            print('Has ganado un punto')
        elif  jugador2 == 'Papel':
            vida -= 1
            print('Has perdido la ronda')
        else:
            print('Has empatado')


    elif jugador1 == 'Papel':
        if jugador2 == 'Piedra':
            vida += 1
            print('Has ganado un punto')
        elif jugador2 == 'Tijera':
            vida -= 1
            print('Has perdido la ronda')
        else:
            print('Has empatado')
   
    elif jugador1 == 'Tijera':
        if jugador2 == 'Papel':
            vida += 1
            print('Has ganado un punto')
        elif jugador2 == 'Piedra':
            vida -= 1
            print('Has perdido la ronda')
        else:
            print('Has empatado')
    else:
        print("La palabra introducida no es válida")
        
if vida == 6:
    print("Te has pasado el juego")
elif vida == 0:
    print("Game over")
# Out:
# Bienvenido al juego Rocio
# Has escogido: Tijera
# Elemento ordenador Papel
# Tijera
# Has escogido: Tijera
# Has empatado
# Tijera
# Has escogido: Papel
# Has perdido la ronda
# Piedra
# Has escogido:
# La palabra introducida no es válida
# Tijera
# Has escogido:
# La palabra introducida no es válida
# Papel
# Has escogido:
# La palabra introducida no es válida
# Piedra
# Has escogido:
# La palabra introducida no es válida
# Papel
# Has escogido:
# La palabra introducida no es válida
# Papel
# Has escogido:
# La palabra introducida no es válida
# Piedra
# Has escogido:
# La palabra introducida no es válida
# Papel
# Has escogido:
# La palabra introducida no es válida
# Tijera
# Has escogido:
# La palabra introducida no es válida
# Papel
# Has escogido:
# La palabra introducida no es válida
# Tijera
# Has escogido:
# La palabra introducida no es válida
# Papel
